# %%
import pandas as pd
import numpy as np
import os
from datetime import date

# %%
df = pd.read_pickle('D:/jaume/Jupyter Notebooks/Vacantes Scraper/ScrapedData/20220505_020738_vacants.pkl')
info = pd.read_pickle('D:/jaume/Jupyter Notebooks/Vacantes Scraper/ScrapedData/20220505_020738_exportInfo.pkl')

# %%
info.head()
# Out:
#   files     vac_types post_types
# 0     1  LD-PA common        NaN
# 1     2     CM common       None
# 2  None   VAC reserve       None
# 3  None   2-16 common       None
# 4  None        single       None

# %%
df.values
# Out:
# array([['02500', 'CUARTEL GENERAL DEL MANDO DE TROPAS DE MONTAÑA',
#         '50083231', ..., '244,604,656,959',
#         Timestamp('2021-03-24 00:00:00'), nan],
#        ['02501', 'BCG DE LA BRIGADA «ALMOGÁVARES» VI, DE PARACAIDISTAS',
#         '50027882', ..., '244,959', Timestamp('2021-03-24 00:00:00'),
#         nan],
#        ['02502', 'BATALLON DE ZAPADORES VI', '50056870', ...,
#         '244,609,959', Timestamp('2021-03-24 00:00:00'), nan],
#        ...,
#        ['05552', 'CENTRO GEOGRAFICO DEL EJÉRCITO DE TIERRA', '53000008',
#         ..., '960', Timestamp('2022-04-01 00:00:00'), nan],
#        ['05553', 'DIRECCION DE INFRAESTRUCTURA', '54630000', ...,
#         '511,656,960', Timestamp('2022-04-01 00:00:00'), nan],
#        ['05554', 'ACADEMIA GENERAL MILITAR', '55105700', ..., '960',
#         Timestamp('2022-04-01 00:00:00'), nan]], dtype=object)

# %%
df[df['empleo'] == 'CTE']
# Out:
#       n_vac                                                uco       ciu  \
# 67    01704                          ESTADO MAYOR DEL EJÉRCITO  51000001
# 68    01705                          ESTADO MAYOR DEL EJÉRCITO  51000001
# 69    01706                          ESTADO MAYOR DEL EJÉRCITO  51000001
# 70    01707                          ESTADO MAYOR DEL EJÉRCITO  51000001
# 71    01708                          ESTADO MAYOR DEL EJÉRCITO  51000001
# ...     ...                                                ...       ...
# 2040  02819  JEFATURA DE LA CUARTA SUBINSPECCION GENERAL DE...  54430001
# 2082  03875                              DIRECCION DE PERSONAL  56200003
# 2401  05551     REGIMIENTO DE OPERACIONES DE INFORMACION N.o 1  50069718
# 2403  05553                       DIRECCION DE INFRAESTRUCTURA  54630000
# 2404  05554                           ACADEMIA GENERAL MILITAR  55105700
#
#              pt asig ta empleo                 efun  \
# ...
