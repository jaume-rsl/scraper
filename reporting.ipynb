# %%
import pandas as pd
import numpy as np
import os
from datetime import date

# %%
df = pd.read_pickle('D:/jaume/Jupyter Notebooks/Vacantes Scraper/ScrapedData/20220505_020738_vacants.pkl')

# %%
df.head(20)
# Out:
#     n_vac                                                uco       ciu  \
# 0   02500     CUARTEL GENERAL DEL MANDO DE TROPAS DE MONTAÑA  50083231
# 1   02501  BCG DE LA BRIGADA «ALMOGÁVARES» VI, DE PARACAI...  50027882
# 2   02502                           BATALLON DE ZAPADORES VI  50056870
# 3   02503                  GRUPO DE ARTILLERIA DE CAMPAÑA VI  50091180
# 4   02504        BATALLON DE CG. DE LA BRIGADA «GALICIA» VII  50027771
# 5   02505                 GRUPO DE ARTILLERIA DE CAMPAÑA VII  50030029
# 6   02506                           BATALLON DE ZAPADORES XI  50013330
# 7   02507                                GRUPO LOGISTICO XII  50045610
# 8   02508                                 GRUPO LOGISTICO XI  50055530
# 9   02509                 GRUPO DE ARTILLERIA DE CAMPAÑA XII  50089452
# 10  02510                          BATALLON DE ZAPADORES XII  50092383
# 11  02511         REGIMIENTO DE INFANTERIA «ARAPILES» N.o 62  51018912
# 12  02512                      REGIMIENTO ACORAZADO «PAVIA»4  51094394
# 13  02513                          BATALLON DE ZAPADORES XVI  50039818
# 14  02514              AGRUPACION DE APOYO LOGISTICO N.o 81.  50038203
# 15  02515   AGRUPACION DE APOYO LOGISTICO N.o 11. (COLMENAR)  50047849
# 16  02516  REGIMIENTO DE ARTILLERIA DE COSTA 4 (SAN FERNA...  50012789
# 17  02517                          CUARTEL GENERAL DEL MING.  50059971
# 18  02518               BATALLON DE HELICOPTEROS DE ATAQUE I  50065595
# 19  02519                         REGIMIENTO DE INGENIEROS 1  50081154
#
#            pt asig ta empleo                    efun             cursos t_max  \
# 0   5WA1E/001   LD  Z   SBMY                     NaN  [TM:E, PA:E, nan]   NaN
# 1   5WA1E/001   LD  Z   SBMY                     NaN  [TM:E, PA:E, nan]   NaN
# 2   5WA1E/001   LD  Z   SBMY                     NaN  [TM:E, PA:E, nan]   NaN
# 3   5WA1E/001   LD  Z   SBMY                     NaN  [TM:E, PA:E, nan]   NaN
# 4   5WA1E/002   LD  Z   SBMY                     NaN  [TM:E, PA:E, nan]   NaN
# 5   5WA1E/001   LD  Z   SBMY                     NaN  [TM:E, PA:E, nan]   NaN
# 6   5WA1E/001   LD  Z   SBMY                     NaN  [TM:E, PA:E, nan]   NaN
# 7   5WA1E/002   LD  Z   SBMY                     NaN  [TM:E, PA:E, nan]   NaN
# 8   5WA1E/002   LD  Z   SBMY                     NaN  [TM:E, PA:E, nan]   NaN
# 9   5WA1E/002   LD  Z   SBMY                     NaN  [TM:E, PA:E, nan]   NaN
# 10  5WA1E/001   LD  Z   SBMY                     NaN  [TM:E, PA:E, nan]   NaN
# 11  5WA1E/001   LD  Z   SBMY                     NaN  [TM:E, PA:E, nan]   NaN
# 12  5WA1E/001   LD  Z   SBMY  [CAB., ING./TRA., nan]                NaN   NaN
# 13  5WA1E/001   LD  Z   SBMY  [CAB., ING./TRA., nan]                NaN   NaN
# 14  5WA1E/001   LD  Z   SBMY  [CAB., ING./TRA., nan]                NaN   NaN
# 15  5WA1E/001   LD  Z   SBMY  [CAB., ING./TRA., nan]                NaN   NaN
# 16  5WA1E/001   LD  Z   SBMY  [CAB., ING./TRA., nan]                NaN   NaN
# 17  5WA1E/001   LD  Z   SBMY  [CAB., ING./TRA., nan]                NaN   NaN
# 18  5WA1E/002   LD  Z   SBMY  [CAB., ING./TRA., nan]                NaN   NaN
# 19  5WA1E/002   LD  Z   SBMY  [CAB., ING./TRA., nan]                NaN   NaN
#
#        t_min                                          fecha_cob    csce  \
# 0        NaN                      [17-05-2021, 25-04-2021, nan]  412,70
# 1        NaN                      [17-05-2021, 25-04-2021, nan]  412,70
# 2        NaN                      [17-05-2021, 25-04-2021, nan]  412,70
# 3        NaN                      [17-05-2021, 25-04-2021, nan]  412,70
# 4        NaN                      [17-05-2021, 25-04-2021, nan]  374,87
# 5        NaN                      [17-05-2021, 25-04-2021, nan]  374,87
# 6        NaN                      [17-05-2021, 25-04-2021, nan]  374,87
# 7        NaN                      [17-05-2021, 25-04-2021, nan]  374,87
# 8        NaN                      [17-05-2021, 25-04-2021, nan]  374,87
# 9        NaN                      [17-05-2021, 25-04-2021, nan]  374,87
# 10       NaN                      [17-05-2021, 25-04-2021, nan]  374,87
# 11       NaN                      [17-05-2021, 25-04-2021, nan]  374,87
# 12  [3, nan]  [30-05-2021, 29-05-2021, 13-04-2021, 26-06-202...  374,87
# 13  [3, nan]  [30-05-2021, 29-05-2021, 13-04-2021, 26-06-202...  374,87
# 14  [3, nan]  [30-05-2021, 29-05-2021, 13-04-2021, 26-06-202...  374,87
# 15  [3, nan]  [30-05-2021, 29-05-2021, 13-04-2021, 26-06-202...  374,87
# 16  [3, nan]  [30-05-2021, 29-05-2021, 13-04-2021, 26-06-202...  374,87
# 17  [3, nan]  [30-05-2021, 29-05-2021, 13-04-2021, 26-06-202...  374,87
# 18  [3, nan]  [30-05-2021, 29-05-2021, 13-04-2021, 26-06-202...  374,87
# 19  [3, nan]  [30-05-2021, 29-05-2021, 13-04-2021, 26-06-202...  374,87
#
#                 obs  fecha_pub cod_cm
# 0   244,604,656,959 2021-03-24    NaN
# 1           244,959 2021-03-24    NaN
# 2       244,609,959 2021-03-24    NaN
# 3       244,607,959 2021-03-24    NaN
# 4           244,959 2021-03-24    NaN
# 5       244,607,959 2021-03-24    NaN
# 6       244,609,959 2021-03-24    NaN
# 7           244,959 2021-03-24    NaN
# 8           244,959 2021-03-24    NaN
# 9       244,607,959 2021-03-24    NaN
# 10      244,609,959 2021-03-24    NaN
# 11  244,604,605,959 2021-03-24    NaN
# 12  244,605,606,959 2021-03-24    NaN
# 13      244,609,959 2021-03-24    NaN
# 14          244,959 2021-03-24    NaN
# 15          244,959 2021-03-24    NaN
# 16  244,607,608,959 2021-03-24    NaN
# 17  244,609,656,959 2021-03-24    NaN
# 18          244,959 2021-03-24    NaN
# 19      244,609,959 2021-03-24    NaN

# %%
df[df['empleo'] == 'CTE']
# Out:
#       n_vac                                                uco       ciu  \
# 67    01704                          ESTADO MAYOR DEL EJÉRCITO  51000001
# 68    01705                          ESTADO MAYOR DEL EJÉRCITO  51000001
# 69    01706                          ESTADO MAYOR DEL EJÉRCITO  51000001
# 70    01707                          ESTADO MAYOR DEL EJÉRCITO  51000001
# 71    01708                          ESTADO MAYOR DEL EJÉRCITO  51000001
# ...     ...                                                ...       ...
# 2040  02819  JEFATURA DE LA CUARTA SUBINSPECCION GENERAL DE...  54430001
# 2082  03875                              DIRECCION DE PERSONAL  56200003
# 2401  05551     REGIMIENTO DE OPERACIONES DE INFORMACION N.o 1  50069718
# 2403  05553                       DIRECCION DE INFRAESTRUCTURA  54630000
# 2404  05554                           ACADEMIA GENERAL MILITAR  55105700
#
#              pt asig ta empleo                 efun  \
# 67    5JA39/006   LD  C    CTE          [TRA., nan]
# 68    5JA39/053   LD  C    CTE          [TRA., nan]
# 69    5JA39/024   LD  C    CTE          [TRA., nan]
# 70    5JA39/031   LD  C    CTE          [TRA., nan]
# 71    5JA39/016   LD  C    CTE          [TRA., nan]
# ...         ...  ... ..    ...                  ...
# 2040  5JA39/007   LD  C    CTE                  NaN
# 2082  5JA39/010   CM  C    CTE                  NaN
# 2401  5WM79/001   PA  C    CTE  [MECMT, TECAP, nan]
# 2403  5WM85/001   PA  C    CTE  [MECMT, TECAP, nan]
# 2404  5WM85/001   PA  C    CTE  [MECMT, TECAP, nan]
#
#                                                  cursos         t_max  \
# 67                                     XF:I, FM:I, EM:I  [10, 4, nan]
# 68                                     XF:I, FM:I, EM:I  [10, 4, nan]
# 69                                     XF:I, FM:I, EM:I  [10, 4, nan]
# 70                                     XF:I, FM:I, EM:I  [10, 4, nan]
# 71                                     XF:I, FM:I, EM:I  [10, 4, nan]
# ...                                                 ...           ...
# 2040                                                NaN            10
# 2082  [PC:W/PW:W, SL:I, RS:I, GL:I, SL:I, RS:I, LP:I...          10.0
# 2401                                                NaN           NaN
# 2403                                                NaN           NaN
# 2404                                                NaN           NaN
#
#          t_min                      fecha_cob    csce             obs  \
# 67         2.0                            NaN  489,98  51,656,763,960
# 68         2.0                            NaN  489,98  51,656,763,960
# 69         2.0                            NaN  489,98  51,656,763,960
# 70         2.0                            NaN  489,98  51,656,763,960
# 71         2.0                            NaN  489,98  51,656,763,960
# ...        ...                            ...     ...             ...
# 2040  [2, nan]  [28-04-2022, 06-09-2022, nan]  310,43     Z85,656,960
# 2082  [3, nan]              [01-08-2022, nan]  499,78         656,960
# 2401       NaN                            NaN  459,48     511,656,960
# 2403       NaN                            NaN  382,37     511,656,960
# 2404       NaN                            NaN  345,64             960
#
#       fecha_pub cod_cm
# 67   2021-03-24    NaN
# 68   2021-03-24    NaN
# 69   2021-03-24    NaN
# 70   2021-03-24    NaN
# 71   2021-03-24    NaN
# ...         ...    ...
# 2040 2022-03-30    NaN
# 2082 2022-03-31   CM21
# 2401 2022-04-01    NaN
# 2403 2022-04-01    NaN
# 2404 2022-04-01    NaN
#
# [261 rows x 16 columns]
